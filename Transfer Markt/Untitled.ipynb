# %%
import pandas as pd
import numpy as np

# %%
contract_2010 = pd.read_csv('/Users/kiprasjunca/Downloads/benfica_contracts_2010.csv')
contract_2011 = pd.read_csv('/Users/kiprasjunca/benfica_contracts_2011.csv')

# %%
contract_2010
# Out:
#         comp_name  region   country  season_start_year       squad player_num  \
# 0   Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# 1   Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# 2   Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# 3   Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# 4   Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# 5   Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# 6   Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# 7   Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# 8   Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# 9   Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# 10  Liga Portugal     NaN  Portugal               2010  SL Benfica          -
# ...

# %%
new_df = contract_2010.drop(['comp_name', 'region', 'country'], axis=1)

# %%
new_df
# Out:
#     season_start_year       squad player_num          player_name  \
# 0                2010  SL Benfica          -              Roberto
# 1                2010  SL Benfica          -         José Moreira
# 2                2010  SL Benfica          -          Júlio César
# 3                2010  SL Benfica          -           David Luiz
# 4                2010  SL Benfica          -               Luisão
# 5                2010  SL Benfica          -               Sidnei
# 6                2010  SL Benfica          -               Jardel
# 7                2010  SL Benfica          -          Fábio Faria
# 8                2010  SL Benfica          -     Roderick Miranda
# 9                2010  SL Benfica          -       Fábio Coentrão
# 10               2010  SL Benfica          -        Lionel Carole
# 11               2010  SL Benfica          -  Maximiliano Pereira
# 12               2010  SL Benfica          -          Luís Filipe
# ...
